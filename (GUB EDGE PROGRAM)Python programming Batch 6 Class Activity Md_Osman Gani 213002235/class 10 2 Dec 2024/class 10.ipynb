# %%
value = input('Input string: ')
print('Total length with space: ',len(value))
count = 0
for i in range(0,len(value),1):
  if(value[i]!=' '):
    count +=1
print('Length of the string without space: ',count)

# %%
li = [1,2,3,10,2,5,6,7,13,20]
newli = []
for i in li:
  if(i%2==0):
    newli.append('True')
  else:
    newli.append('False')
print(newli)

# %%
dic = {
    1:'Tamim',
    2:'Osman',
    3:'Tanim',
    4:'Tanvir',
    5:'Sajib',
    6:'Rohan'
}
for i,k in dic.items():
  if(i%2==0):

# %%
mydic ={


        1:"one",
        2:"two",
        3:"three",
        4:"four",
        5:"five",
        6:"six",
        7:"seven",
        8:"eight",
        9:"nine",
        10:"ten"
}

var =int(input("enter number between 0 to 10: "))

print(mydic[var])
# Out:
# enter number between 0 to 10: 5
# five

# %%
for i in range(1,5):
  print(f'({i} , {2*i})')
# Out:
# (1 , 2)
# (2 , 4)
# (3 , 6)
# (4 , 8)

# %%
from math import tan
import math

theta= int(input())
theta = math.radians(theta)
tan=math.tan(theta)
print(tan)

for i in range(0,21):
  print(f'({i} , {(tan*i).2f})')
# Out:
#   File "<ipython-input-16-7062c55b4d57>", line 10
#     print(f'({i} , {(tan*i).2f})')
#            ^
# SyntaxError: invalid decimal literal
