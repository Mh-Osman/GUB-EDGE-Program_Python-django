# %%
import numpy as np
import pandas as pd

# %%
np.random.seed(42)
data = np.random.randn(10000)


mean_value = np.mean(data)
median_value = np.median(data)
std_dev = np.std(data)



min_value = np.min(data)
max_value = np.max(data)



count_above_mean = np.sum(data > mean_value)



normalized_data = (data - min_value) / (max_value - min_value)



print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Standard Deviation: {std_dev}")
print(f"Minimum Value: {min_value}")
print(f"Maximum Value: {max_value}")
print(f"Number of values greater than the mean: {count_above_mean}")
print(f"First 10 normalized values: {normalized_data[:10]}")
# Out:
# Mean: -0.002135983368426207
# Median: -0.0025949757928775408
# Standard Deviation: 1.0034122061299875
# Minimum Value: -3.9224002516183423
# Maximum Value: 3.9262377064363267
# Number of values greater than the mean: 4997
# First 10 normalized values: [0.5630422  0.48213919 0.58227795 0.69380575 0.4699219  0.46992399
#  0.70096405 0.59753489 0.4399395  0.56888346]
