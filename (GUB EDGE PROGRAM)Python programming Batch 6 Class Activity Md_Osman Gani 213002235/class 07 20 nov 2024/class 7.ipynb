# %% [markdown]
# list

# %%
list = ["a" , "b" , "3"," e" , "2"]

for x in range(0,len(list)):
  print(list[x])
# Out:
# a
# b
# 3
#  e
# 2

# %%
for x in list[ : :-1]:
  print(x)
# Out:
# a
# b
# 3
#  e
# 2

# %%
list =[]

for x in range(5):
  a=input()
  list.append(a)


for x in list:
  x.uppercasehvs
  print(x)

# %%
list =[]

for x in range(5):
  a=input()
  list.append(a)


for x in list:
  if(x[0] == 'b'):
     print(x)
# Out:
# bable
# babul
# osman
# abul
# billu
# bable
# babul
# billu

# %%
list =[]

for x in range(5):
  a=int(input())
  list.append(a)


for x in list:
  if(x <20 and x>10):
     print(x)
# Out:
# 10
# 25
# 1
# 4
# 15
# 15

# %%
colors = ["pink","yello" , "red" , "blue" , "green"]


#without comprehensive

newcol=[]
for x in colors:
  if 'e' in x:
    newcol.append(x)

# %%
# with comprehensive
colors = ["pink","yello" , "red" , "blue" , "green"]



newcol= [x for x in colors if 'e' in x]
print(newcol)
