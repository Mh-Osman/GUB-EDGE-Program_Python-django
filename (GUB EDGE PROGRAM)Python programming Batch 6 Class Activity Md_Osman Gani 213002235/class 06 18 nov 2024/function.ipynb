# %%
def function_name():
  print("hello world")

# %%
function_name()
# Out:
# hello world

# %%
def multiplier(num:float):
  for x in range(1,11):
    print(num*x)

multiplier(3)
# Out:
# 3
# 6
# 9
# 12
# 15
# 18
# 21
# 24
# 27
# 30

# %%
def show(fname , lname=" "):
  print(f"{fname + lname} ", end=' ')
  print()

# %%
show("osman", " gani")
show("osman")
# Out:
# osman gani
# osman

# %%
def show():
  a=32
  b=12
  return (a+b)
print(show())
# Out:
# 44

# %%
a=30
def fun():
  a=10
  print(a)

def show():
  print(a)

fun()
show()
# Out:
# 10
# 30

# %%
(lambda x:x+2)(2)
# Out:
# 4

# %%
def area_calculate(a):
    pi = 3.141641
    print("Area of a circale: ",pi*(a**2))
    print("Area of rectangle: ",a**2)

area = int(input("Input area: "))
area_calculate(area)

# %%
name=input("Input name: ")
size = len(name.replace(' ',""))
print('Size of string : ',size)

# %%
total_marks = float(input('Enter the total marks: '))
obtained_marks=float(input('Enter the obtain marks: '))

# %%
percentage = float(obtained_marks/total_marks)*100
print(percentage)
print(f'The percentage is : {percentage: .2f}%')

# %%
def fun():
  n=int(nput())
